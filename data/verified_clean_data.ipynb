# %%
import pandas as pd

# Especifica el separador que usamos para guardar
df = pd.read_csv('./files/Violencia_Intrafamiliar_Limpio.csv', sep=';', low_memory=False)

# Para verificar que ahora sí tiene las columnas separadas
print(df.head())
print(f"Columnas detectadas: {df.columns.tolist()}")

print(df.shape)
# Out:
#       ANO    MES   DIA             DEPTOMCPIO    AREA VIC_SEXO  VIC_EDAD  \
# 0  2011.0  Enero   2.0  San Juan Sacatep�quez  Urbana  Mujeres      28.0
# 1  2011.0  Enero   4.0  San Juan Sacatep�quez   Rural  Mujeres      24.0
# 2  2011.0  Enero   7.0  San Juan Sacatep�quez   Rural  Mujeres      24.0
# 3  2011.0  Enero  23.0  San Juan Sacatep�quez  Urbana  Mujeres      28.0
# 4  2011.0  Enero  18.0  San Juan Sacatep�quez   Rural  Mujeres      32.0
#
#     VIC_EST_CIV               VIC_ESCOLARIDAD  VIC_REL_AGR  TOTAL_HIJOS  \
# 0  Solteros(as)  Grado universitario ignorado  Conviviente          1.0
# 1   Casados(as)                Sexto primaria   Esposos(a)          2.0
# 2   Casados(as)   Divesificado grado ignorado   Esposos(a)          1.0
# 3    Unidos(as)   Divesificado grado ignorado  Conviviente          3.0
# 4    Unidos(as)                       Ninguna  Conviviente          5.0
#
#   AGR_SEXO  AGR_EDAD   AGR_GRUPET                         TIPAGRE  \
# ...

# %%
# Especifica el separador que usamos para guardar
df = pd.read_csv('./files/Divorcios_Limpio.csv', sep=';', low_memory=False)

# Para verificar que ahora sí tiene las columnas separadas
print(df.head())
print(f"Columnas detectadas: {df.columns.tolist()}")

print(df.shape)
# Out:
#       ANO   MES   DIA  DEPTO  MUNICIPIO  EDAD_HOM  EDAD_MUJ  ETNIA_HOM  \
# 0  2017.0  12.0   4.0    8.0        801      47.0     999.0        9.0
# 1  2017.0   8.0   5.0    1.0        101     999.0     999.0        9.0
# 2  2017.0   5.0  23.0    1.0        101      33.0      31.0        4.0
# 3  2017.0   7.0   7.0    1.0        101     999.0     999.0        9.0
# 4  2017.0   7.0  20.0    1.0        101     999.0     999.0        9.0
#
#    ETNIA_MUJ  ESCOLARIDAD_HOM  ESCOLARIDAD_MUJ OCUPACION_HOM OCUPACION_MUJ
# 0        9.0              1.0              1.0          99.0          99.0
# 1        9.0              9.0              9.0          99.0           3.0
# 2        4.0              9.0              9.0          52.0          11.0
# 3        9.0              9.0              9.0          26.0          12.0
# 4        9.0              9.0              9.0          21.0          21.0
# ...
